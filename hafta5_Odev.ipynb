# %% [markdown]
# # Ahmet Burak Şişci

# %% [markdown]
# ### ödev: aşağıdaki grafiği yorumla

# %% [markdown]
# ![WhatsApp Görsel 2025-10-13 saat 14.08.34_f5605b4e.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Burada lamda dediğimiz deger yani beklenen deger ortalamaya eşittir.
# Ve poission da varyans ve ortalama lamda ya eşittir.Bu sayede oradan standart sapmaya geçip dağılım hakkında yorum yapabilirz.
# Yani standart sapma arttıkca beklenen deger , lamda da artar yani bu da verilerin ortalama etrafında daha geniş bir aralığa yayılması anlamına gelir.Eğri gittikçe yayılır ve normale yakınsar.

# %% [markdown]
# λ arttıkça Poisson dağılımı Normal dağılıma yakınsar, bu da basıklığın azalması ve dağılımın daha yayvan hale gelmesi demektir!

# %% [markdown]
# λ arttıkça Poisson dağılımı Normal dağılıma yakınsar, bu da basıklığın azalması ve dağılımın daha yayvan hale gelmesi demektir.#Ayrıca lamda arttıkca müşteri sayısı ortlamasına gore daha az değişken olur

# %% [markdown]
# ### Anıl Elmaz'a teşekkürler.
